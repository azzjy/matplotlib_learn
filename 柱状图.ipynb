# %%
'''
使用bar函数可以绘制柱状图。柱状图需要水平的x坐标值，以及每个x坐标值对应的y坐标值，从而形成柱状图。
柱状图主要用来纵向对比和横向对比的/
'''
# Out:
# '\n使用bar函数可以绘制柱状图。柱状图需要水平的x坐标值，以及每个x坐标值对应的y坐标值，从而形成柱状图。\n柱状图主要用来纵向对比和横向对比的/\n'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1980,1985,1990,1995]
x_labels=['1980-year','1985-year','1990-year','1995-year']
y = [1000,3000,4000,5000]
plt.xticks(x,x_labels)
plt.bar(x,y,width=3)
plt.xlabel('year')
plt.ylabel('number')
plt.title('title')
plt.show()

# %%
np.random.seed(0)
x=np.arange(5)
y=np.random.randint(-5,5,5)
print(x,y)
#将画布分割成一行两列
plt.subplot(1,2,1)
#在第一列中画线
v_bar = plt.bar(x,y)
#在水平0的位置画一条蓝线
plt.axhline(0,color='blue',linewidth=2)
plt.subplot(1,2,2)
#barh将y和x轴对换，竖着方向为x轴
h_bar = plt.barh(x,y,color='red')
#在第二列的画布中0位置处画红色的线
plt.axvline(0,color='red',linewidth=2)
# Out:
# [0 1 2 3 4] [ 0 -5 -2 -2  2]

# %%
#三天中三部电影的票房变化
real_names=['qianyuqianxun','wanjuzongdongyuan4','heiyiren'] 
real_num1=[5453,7548,6543]
real_num2=[1840,4013,3421]
real_num3=[1080,1673,2342]
#生成x 第1天 第2天 第3天 
x=np.arange(len(real_names))
x_label=['{}day'.format(i+1) for i in range(len(real_names))]
#绘制柱状图
#设置柱的宽度
width=0.3
plt.bar(x,real_num1,color='g',width=width,label=real_names[0])
plt.bar([i+width for i in x],real_num2,color='b',width=width,label=real_names[1])
plt.bar([i+2*width for i in x],real_num3,color='r',width=width,label=real_names[2])
#修改x坐标
plt.xticks([i+width for i in x],x_label)
#添加图例
plt.legend()
#添加标题
plt.title('3 day number')
plt.show()
